# %% [markdown]
# # Translation from English to kannada using sequence to sequence model

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Loading Data and then preprocessing

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase,remove non-letter characters


def normalizeString(s):
    s = s.lower().strip()
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[.!?]+", r" ", s)
    return s

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('dataset_eng_kan.txt',encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 22

eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)


def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH #and \
        #p[0].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# # Data preparation

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('eng', 'kan', False)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 555 sentence pairs
# Trimmed to 319 sentence pairs
# Counting words...
# Counted words:
# eng 1450
# kan 1770
# ['european high representative/vice president (hrvp) hjosep borrell fontelles calls on prime minister shri narendra modi', 'ಯುರೋಪ್ ಉನ್ನತ ಪ್ರತಿನಿಧಿ/ ಉಪಾಧ್ಯಕ್ಷ (ಎಚ್ ರ್ ಿ ಿಘನತೆವೆತ್ತ ಜೋಸೆಪ್ ಬೋರೆಲ್ ಫಾಂಟೆಲ್ಸ್ ಅವರಿಂದು ಪ್ರಧಾನಮಂತ್ರಿ ಶ್ರೀ ನರೇಂದ್ರ ಮೋದಿ ಅವರನ್ನು ಭೇಟಿ ಮಾಡಿದರು  ']

# %% [markdown]
# # Sequence to Sequence (Seq2Seq) model
# ## Encoder

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# ## Decoder

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# ## Attention for Decoder

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# # Training

# %% [markdown]
# ## Preparing Training Data

# %%
def indexesFromSentence(lang, sentence):
    # %matplotlib inline
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# ## Training the model

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()
    # %matplotlib inline

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %% [markdown]
# #### estimated time remaining given the current time and progress in % for training

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
#train the model with the given no.of iteration and estimation the loss for the training
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    # %matplotlib inline
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# ## Plotting the result of training loss wrt the no.of iteration

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    # %matplotlib inline
    plt.figure()
    fig, ax = plt.subplots()
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# # Evaluation

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    # %matplotlib inline
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=50):
    from nltk.translate.bleu_score import sentence_bleu
    # %matplotlib inline
    total=0
    average=0
    
    for i in range(n):
        pair = random.choice(pairs)
        print('English: ', pair[0])
        print('Actual: ', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('Predicted: ', output_sentence)
        act = pair[1].split()
        pred = output_sentence.split()
        print('Cumulative 1-gram: %f' % sentence_bleu([act], pred, weights=(1, 0, 0, 0)))
        print('Cumulative 2-gram: %f' % sentence_bleu([act], pred, weights=(0.5, 0.5, 0, 0)))
        print('Cumulative 3-gram: %f' % sentence_bleu([act], pred, weights=(0.33, 0.33, 0.33, 0)))
        print('Cumulative 4-gram: %f' % sentence_bleu([act], pred, weights=(0.25, 0.25, 0.25, 0.25)))
        score = sentence_bleu([act], pred)
        print(score)
        print('')
        total+=score
    average=total/n
    print("Average BLEU score")
    print(average)

# %% [markdown]
# # Training and  evaluating

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

trainIters(encoder1, attn_decoder1, 7000, print_every=500)
# Out:
# 0m 55s (- 12m 0s) (500 7%) 4.9736
# 1m 39s (- 9m 59s) (1000 14%) 5.1515
# 2m 23s (- 8m 45s) (1500 21%) 4.5982
# 3m 4s (- 7m 40s) (2000 28%) 4.2412
# 3m 48s (- 6m 51s) (2500 35%) 4.2313
# 4m 33s (- 6m 4s) (3000 42%) 3.9011
# 5m 19s (- 5m 19s) (3500 50%) 3.4824
# 6m 6s (- 4m 34s) (4000 57%) 3.0643
# 6m 52s (- 3m 49s) (4500 64%) 2.5849
# 7m 17s (- 2m 54s) (5000 71%) 2.0269
# 7m 39s (- 2m 5s) (5500 78%) 1.6441
# 8m 5s (- 1m 20s) (6000 85%) 1.1389
# 8m 29s (- 0m 39s) (6500 92%) 1.0442
# 8m 53s (- 0m 0s) (7000 100%) 0.6251

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# English:  the collaboration between india and sweden in polar science will enable sharing of the expertise available with both countries
# Actual:  ಭಾರತ ಮತ್ತು ಸ್ವೀಡನ್ ನಡುವಿನ ಧ್ರುವ ವಿಜ್ಞಾನದ ಸಹಯೋಗವು ಎರಡೂ ದೇಶಗಳು ಲಭ್ಯವಿರುವ ಪರಿಣತಿಯನ್ನು ಪರಸ್ಪರ ಹಂಚಿಕೊಳ್ಳಲು ಅನುವು ಮಾಡಿಕೊಡುತ್ತದೆ
# Predicted:  ಭಾರತ ಮತ್ತು ಸ್ವೀಡನ್ ನಡುವಿನ ಧ್ರುವ ವಿಜ್ಞಾನದ ಸಹಯೋಗವು ಎರಡೂ ದೇಶಗಳು ಲಭ್ಯವಿರುವ ಪರಿಣತಿಯನ್ನು ಪರಸ್ಪರ ಹಂಚಿಕೊಳ್ಳಲು ಅನುವು ಮಾಡಿಕೊಡುತ್ತದೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  first, to reinforce indias ancient culture of giving importance to every individuals duties and obligations
# Actual:  ಮೊದಲನೆಯದಾಗಿ, ಪ್ರತಿಯೊಬ್ಬ ವ್ಯಕ್ತಿಯ ಕರ್ತವ್ಯಗಳು ಮತ್ತು ಕಟ್ಟುಪಾಡುಗಳಿಗೆ ಪ್ರಾಮುಖ್ಯತೆ ನೀಡುವ ಭಾರತದ ಪ್ರಾಚೀನ ಸಂಸ್ಕೃತಿಯನ್ನು ಪುನಶ್ಚೈತನ್ಯಗೊಳಿಸಿ
# Predicted:  ಮೊದಲನೆಯದಾಗಿ, ಪ್ರತಿಯೊಬ್ಬ ವ್ಯಕ್ತಿಯ ಕರ್ತವ್ಯಗಳು ಮತ್ತು ಕಟ್ಟುಪಾಡುಗಳಿಗೆ ಪ್ರಾಮುಖ್ಯತೆ ಭಾರತದ ಪ್ರಾಚೀನ ಸಂಸ್ಕೃತಿಯನ್ನು ಪುನಶ್ಚೈತನ್ಯಗೊಳಿಸಿ
# Cumulative 1-gram: 0.913101
# Cumulative 2-gram: 0.866243
# Cumulative 3-gram: 0.811710
# Cumulative 4-gram: 0.742614
# 0.7426141117870939
#
# English:  the prime minister, shri narendra modi, will visit karnataka on 2ndand 3rdjanuary 2020
# Actual:  ಪ್ರಧಾನಮಂತ್ರಿ ಶ್ರೀ ನರೇಂದ್ರ ಮೋದಿ ಅವರು 2020 ಜನವರಿ 2 ಮತ್ತು 3ರಂದು ಕರ್ನಾಟಕಕ್ಕೆ ಭೇಟಿ ನೀಡಲಿದ್ದಾರೆ
# Predicted:  ಪ್ರಧಾನಮಂತ್ರಿ ಶ್ರೀ ನರೇಂದ್ರ ಮೋದಿ ಅವರು 2020 ಜನವರಿ 2 ಮತ್ತು 3ರಂದು ಕರ್ನಾಟಕಕ್ಕೆ ಭೇಟಿ ನೀಡಲಿದ್ದಾರೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  protecting the tiger and the lion
# Actual:  ಹುಲಿ ಮತ್ತು ಸಿಂಹ ಸಂರಕ್ಷಣೆ
# Predicted:  ಹುಲಿ ಮತ್ತು ಸಿಂಹ ಸಂರಕ್ಷಣೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  i am happy that atal tinkering labs have been set up in thousands of schools across the country
# Actual:  ದೇಶಾದ್ಯಂತ ಸಾವಿರಾರು ಶಾಲೆಗಳಲ್ಲಿ ಅಟಲ್ ಟಿಂಕರಿಂಗ್ ಲ್ಯಾಬ್‌ಗಳನ್ನು ಸ್ಥಾಪಿಸಲಾಗಿದೆ ಎಂಬುದು ನನಗೆ ಸಂತೋಷದ ವಿಚಾರವಾಗಿದೆ
# Predicted:  ಇದೇ ಆಶಯ ದೇಶದ ಬಡವರು, ಉಕ್ಕು ಬಳಸಲಾಗಿದೆ, ಈ ಪೈಕಿ 23ಸಾವಿರ ಟನ್ ಹೈ ಟೆನ್ಸಿಲ್ ಮಿಶ್ರ ಸ್ಟೀಲ್ ಬಳಕೆಯಾಗಿದೆ
# Cumulative 1-gram: 0.000000
# Cumulative 2-gram: 0.000000
# Cumulative 3-gram: 0.000000
# Cumulative 4-gram: 0.000000
# 0
#
# English:  pm to lay foundation stone for memorial museum of shri shri shivakumar swamiji
# Actual:  ಶ್ರೀ ಶ್ರೀ ಶಿವಕುಮಾರ ಸ್ವಾಮೀಜಿ ಸ್ಮಾರಕ ವಸ್ತು ಸಂಗ್ರಹಾಲಯಕ್ಕೆ ಶಂಕುಸ್ಥಾಪನೆ
# Predicted:  ಶ್ರೀ ಶ್ರೀ ಶಿವಕುಮಾರ ಸ್ವಾಮೀಜಿ ಸ್ಮಾರಕ ವಸ್ತು ಸಂಗ್ರಹಾಲಯಕ್ಕೆ ಶಂಕುಸ್ಥಾಪನೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  may his soul rest in peace, the prime minister said
# Actual:  ಅವರ ಆತ್ಮಕ್ಕೆ ಶಾಂತಿ ದೊರಕಲಿ” ಎಂದು ಪ್ರಧಾನಮಂತ್ರಿ ಹೇಳಿದರು
# Predicted:  ಅವರ ಆತ್ಮಕ್ಕೆ ಶಾಂತಿ ದೊರಕಲಿ” ಎಂದು ಪ್ರಧಾನಮಂತ್ರಿ ಹೇಳಿದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  in september last year, i had the honour of saying a few lines in tamil during my united nations addresse said
# Actual:  ಕಳೆದ ವರ್ಷ ಸೆಪ್ಟೆಂಬರ್ ನಲ್ಲಿ ನನ್ನ ವಿಶ್ವ ಸಂಸ್ಥೆಯ ಭಾಷಣದ ವೇಳೆ ಕೆಲವು ಸಾಲುಗಳನ್ನು ತಮಿಳು ಭಾಷೆಯಲ್ಲಿ ಹೇಳುವ ಗೌರವ ನನಗೆ ಸಿಕ್ಕಿತ್ತು” ಎಂದು ಹೇಳಿದರು
# Predicted:  ಕಳೆದ ವರ್ಷ ಸೆಪ್ಟೆಂಬರ್ ನಲ್ಲಿ ನನ್ನ ವಿಶ್ವ ಸಂಸ್ಥೆಯ ಭಾಷಣದ ವೇಳೆ ಕೆಲವು ಸಾಲುಗಳನ್ನು ಸಾಲುಗಳನ್ನು ಸಾಲುಗಳನ್ನು ಸಿಕ್ಕಿತ್ತು” ಎಂದು ಅವರು ಹೇಳಿದರು
# Cumulative 1-gram: 0.732126
# Cumulative 2-gram: 0.668933
# Cumulative 3-gram: 0.622545
# Cumulative 4-gram: 0.590096
# 0.590096156808963
#
# English:  pm talks to the president of united states, donald trump
# Actual:  ಅಮೆರಿಕ ಅಧ್ಯಕ್ಷ ಶ್ರೀ ಡೊನಾಲ್ಡ್ ಟ್ರಂಪ್ ಜೊತೆ ಪ್ರಧಾನಮಂತ್ರಿ ಮಾತುಕತೆ
# Predicted:  ಅಮೆರಿಕ ಅಧ್ಯಕ್ಷ ಶ್ರೀ ಡೊನಾಲ್ಡ್ ಟ್ರಂಪ್ ಜೊತೆ ಪ್ರಧಾನಮಂತ್ರಿ ಮಾತುಕತೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  exams are important, but exams are not life
# Actual:  ಪರೀಕ್ಷೆಗಳು ಮುಖ್ಯ, ಆದರೆ ಪರೀಕ್ಷೆಗಳೇ ಜೀವನವಲ್ಲ
# Predicted:  ಅದೇ ರೀತಿ ಪರೀಕ್ಷೆ ಸಹ ನಮ್ಮ ಇಡೀ
# Cumulative 1-gram: 0.000000
# Cumulative 2-gram: 0.000000
# Cumulative 3-gram: 0.000000
# Cumulative 4-gram: 0.000000
# 0
#
# English:  it does not give them any importance
# Actual:  ಅದು ಅವರಿಗೆ ಯಾವುದೇ ಪ್ರಾಮುಖ್ಯತೆಯನ್ನು ನೀಡುವುದಿಲ್ಲ
# Predicted:  ಅದು ಅವರಿಗೆ ಯಾವುದೇ ಪ್ರಾಮುಖ್ಯತೆಯನ್ನು ನೀಡುವುದಿಲ್ಲ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  he said that this would enhance the synergy between policy makers and various stakeholders
# Actual:  ಇದು ನೀತಿ ನಿರೂಪಕರು ಮತ್ತು ವಿವಿಧ ಪಾಲುದಾರರ ನಡುವಿನ ಸಮನ್ವಯ ಹೆಚ್ಚಿಸುತ್ತದೆ
# Predicted:  ಇದು ನೀತಿ ನಿರೂಪಕರು ಮತ್ತು ವಿವಿಧ ಪಾಲುದಾರರ ನಡುವಿನ ಸಮನ್ವಯ ಹೆಚ್ಚಿಸುತ್ತದೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  he will also distribute kisan credit cards (kcc) to select farmers of karnataka
# Actual:  ಕಿಸಾನ್ ಕ್ರಿಡಿಟ್ ಕಾರ್ಡ್ (ಕೆಸಿಸಿ)ಗಳನ್ನು ಸಹ ಅವರು ಕರ್ನಾಟಕದ ಆಯ್ದ ರೈತರಿಗೆ ವಿತರಣೆ ಮಾಡಲಿದ್ದಾರೆ
# Predicted:  ಕರ್ನಾಟಕದ ಆಯ್ದ ರೈತರಿಗೆ ಕಿಸಾನ್ ಕ್ರೆಡಿಟ್ ಕಾರ್ಡ್‌ಗಳನ್ನು (ಕೆಸಿಸಿ) ವಿತರಿಸಿದರು
# Cumulative 1-gram: 0.343645
# Cumulative 2-gram: 0.259771
# Cumulative 3-gram: 0.200201
# Cumulative 4-gram: 0.000000
# 3.297337141451012e-78
#
# English:  i am confident that under his leadership, oman will continue to progress and prosper and contribute to global peace
# Actual:  ಅವರ ನಾಯಕತ್ವದಲ್ಲಿ ಒಮನ್ ನ ಪ್ರಗತಿ ಮತ್ತು ಅಭ್ಯುದಯ ಮುಂದುವರಿಯುವುದಲ್ಲದೆ, ಜಾಗತಿಕ ಶಾಂತಿಗೆ ಕೊಡುಗೆ ನೀಡಲಿದೆ ಎಂಬ ಭರವಸೆ ನನಗಿದೆ
# Predicted:  ಅವರ ನಾಯಕತ್ವದಲ್ಲಿ ಒಮನ್ ನ ಪ್ರಗತಿ ಮತ್ತು ಅಭ್ಯುದಯ ಮುಂದುವರಿಯುವುದಲ್ಲದೆ, ಜಾಗತಿಕ ಶಾಂತಿಗೆ ಕೊಡುಗೆ ನೀಡಲಿದೆ ಎಂಬ ಎಂದರು
# Cumulative 1-gram: 0.864558
# Cumulative 2-gram: 0.861997
# Cumulative 3-gram: 0.859837
# Cumulative 4-gram: 0.855947
# 0.8559471626823624
#
# English:  prime minister also expressed his condolence on the untimely demise of former high commissioner of bangladesh to india syed muazzem ali
# Actual:  ಭಾರತಕ್ಕೆ ಬಾಂಗ್ಲಾದೇಶದ ಮಾಜಿ ಹೈಕಮಿಷನರ್ ಸೈಯದ್ ಮುಜೀಂ ಅಲಿ ಅವರ ಅಕಾಲಿಕ ನಿಧನದ ಬಗ್ಗೆ ಪ್ರಧಾನಿ ಸಂತಾಪ ಸೂಚಿಸಿದರು 019 ರಲ್ಲಿ ಭಾರತ-ಬಾಂಗ್ಲಾದೇಶ ಸಂಬಂಧದಲ್ಲಿ ಸಾಧಿಸಿದ ಪ್ರಗತಿಯ ಬಗ್ಗೆ ಪ್ರಧಾನಿ ಗಮನ ಸೆಳೆದರು
# Predicted:  ಭಾರತಕ್ಕೆ ಬಾಂಗ್ಲಾದೇಶದ ಮಾಜಿ ಹೈಕಮಿಷನರ್ ಸೈಯದ್ ಮುಜೀಂ ಅಲಿ ಅವರ ಅಕಾಲಿಕ ನಿಧನದ ಬಗ್ಗೆ ಪ್ರಧಾನಿ ಸಂತಾಪ ಸೂಚಿಸಿದರು 019 ರಲ್ಲಿ ಭಾರತ-ಬಾಂಗ್ಲಾದೇಶ ಸಂಬಂಧದಲ್ಲಿ ಸಾಧಿಸಿದ ಪ್ರಗತಿಯ ಬಗ್ಗೆ ಪ್ರಧಾನಿ ಗಮನ ಸೆಳೆದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  the bill with the official amendments was passed by the rajya sabha on 31st july, 2019
# Actual:  31 ಜುಲೈ, 2019 ರಂದು ತಿದ್ದುಪಡಿಗಳೊಂದಿಗೆ ಮಸೂದೆಯನ್ನು ರಾಜ್ಯಸಭೆಯು ಅಂಗೀಕರಿಸಿತು
# Predicted:  ನಂತರ, ಈ ಮಸೂದೆಯನ್ನು ರಾಜ್ಯಸಭೆಯಲ್ಲಿ 2019 ರ ಜುಲೈ 31 ರಂದು ಮಂಡಿಸಲಾಯಿತು
# Cumulative 1-gram: 0.400000
# Cumulative 2-gram: 0.000000
# Cumulative 3-gram: 0.000000
# Cumulative 4-gram: 0.000000
# 1.4488496539373276e-231
#
# English:  pm pays tributes to savitribai phule on her jayanti
# Actual:  ಸಾವಿತ್ರಿಬಾಯಿ ಫುಲೆ ಜಯಂತಿ: ಪ್ರಧಾನಮಂತ್ರಿ ಗೌರವ ನಮನ
# Predicted:  ಸಾವಿತ್ರಿಬಾಯಿ ಫುಲೆ ಫುಲೆ ಪ್ರಧಾನಮಂತ್ರಿ
# Cumulative 1-gram: 0.454898
# Cumulative 2-gram: 0.303265
# Cumulative 3-gram: 0.000000
# Cumulative 4-gram: 0.000000
# 6.397495320955232e-155
#
# English:  technology is the bridge between the government and the common man
# Actual:  ತಂತ್ರಜ್ಞಾನವು ಸರ್ಕಾರ ಮತ್ತು ಜನ ಸಾಮಾನ್ಯರ ನಡುವಿನ ಸೇತುವೆಯಾಗಿದೆ
# Predicted:  ತಂತ್ರಜ್ಞಾನವು ಸರ್ಕಾರ ಮತ್ತು ಜನ ಸಾಮಾನ್ಯರ ನಡುವಿನ ಸೇತುವೆಯಾಗಿದೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  pm visits sree siddaganga mutt, lays foundation stone for memorial museum of shri shri shivakumar swamiji
# Actual:  ಸಿದ್ದಗಂಗಾ ಮಠಕ್ಕೆ ಪ್ರಧಾನಮಂತ್ರಿ ಭೇಟಿಶ್ರೀ ಶ್ರೀ ಶಿವಕುಮಾರ ಸ್ವಾಮೀಜಿ ಸ್ಮಾರಕ ವಸ್ತು ಸಂಗ್ರಹಾಲಯಕ್ಕೆ ಶಂಕುಸ್ಥಾಪನೆ
# Predicted:  ಶ್ರೀ ಶ್ರೀ ಶಿವಕುಮಾರ ಪ್ರಧಾನಮಂತ್ರಿ ಶ್ರೀ ಶಿವಕುಮಾರ ಸ್ವಾಮೀಜಿ ಸ್ಮಾರಕ ವಸ್ತು ಸಂಗ್ರಹಾಲಯಕ್ಕೆ ಶಂಕುಸ್ಥಾಪನೆ
# Cumulative 1-gram: 0.727273
# Cumulative 2-gram: 0.660578
# Cumulative 3-gram: 0.626484
# Cumulative 4-gram: 0.590047
# 0.5900468726392808
#
# English:  the council of scientific and industrial research, at rank 155, was our highest in the scimago institutions rankings (sir) for research
# Actual:  ವೈಜ್ಞಾನಿಕ ಮತ್ತು ಕೈಗಾರಿಕಾ ಸಂಶೋಧನಾ ಮಂಡಳಿ ಸಂಶೋಧನೆಯಲ್ಲಿ 155ನೇ ಸ್ಥಾನದಲ್ಲಿರುವುದೇ ಸಿಮಾಗೋ ಸಂಸ್ಥೆಗಳ ಶ್ರೇಣೀಕರಣದಲ್ಲಿ  ಅತ್ಯುನ್ನತವಾದುದಾಗಿದೆ
# Predicted:  ವೈಜ್ಞಾನಿಕ ಮತ್ತು ಕೈಗಾರಿಕಾ ಸಂಶೋಧನಾ ಮಂಡಳಿ ಸಂಶೋಧನೆಯಲ್ಲಿ 155ನೇ ಸ್ಥಾನದಲ್ಲಿರುವುದೇ ಸಿಮಾಗೋ ಸಂಸ್ಥೆಗಳ ಶ್ರೇಣೀಕರಣದಲ್ಲಿ  ಅತ್ಯುನ್ನತವಾದುದಾಗಿದೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  this is the power of positive motivation, he said
# Actual:  ಇದು ಸಕಾರಾತ್ಮಕ ಪ್ರೇರಣೆಯ ಶಕ್ತಿಎಂದು ಅವರು ಹೇಳಿದರು
# Predicted:  ಈ ಮನಸ್ಥಿತಿಯಿಂದ ನೀವು ಹೊರಬರಬೇಕು ಎಂದು ಅವರು ಹೇಳಿದರು
# Cumulative 1-gram: 0.285714
# Cumulative 2-gram: 0.218218
# Cumulative 3-gram: 0.000000
# Cumulative 4-gram: 0.000000
# 6.968148412761692e-155
#
# English:  governor of west bengal shri jagdeep dhankhar, chief minister msmata banerjee and other dignitaries were present on the occasion
# Actual:  ಪಶ್ಚಿಮ ಬಂಗಾಳದ ರಾಜ್ಯಪಾಲ ಶ್ರೀ ಜಗದೀಪ್ ಧನಕರ್, ಮುಖ್ಯಮಂತ್ರಿ ಕುಮಾರಿ ಮಮತಾ ಬ್ಯಾನರ್ಜಿ ಮತ್ತು ಇತರ ಗಣ್ಯರು ಸಮಾರಂಭದಲ್ಲಿ ಭಾಗಿಯಾಗಿದ್ದರು
# Predicted:  ಪಶ್ಚಿಮ ಬಂಗಾಳದ ರಾಜ್ಯಪಾಲ ಶ್ರೀ ಜಗದೀಪ್ ಧನಕರ್, ಮುಖ್ಯಮಂತ್ರಿ ಕುಮಾರಿ ಮಮತಾ ಬ್ಯಾನರ್ಜಿ ಮತ್ತು ಇತರ ಗಣ್ಯರು ಸಮಾರಂಭದಲ್ಲಿ ಭಾಗಿಯಾಗಿದ್ದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  in this spirit we should celebrate his 250th birth anniversary as a festival of grandeur
# Actual:  ಈ ಸ್ಫೂರ್ತಿಯಲ್ಲಿ ನಾವು ಅವರ 250ನೇ ಜಯಂತಿಯನ್ನು ಹಿರಿಮೆಯ ಹಬ್ಬವಾಗಿ ಆಚರಿಸಬೇಕು ಎಂದು ಹೇಳಿದರು
# Predicted:  ಈ ಸ್ಫೂರ್ತಿಯಲ್ಲಿ ನಾವು ಅವರ 250ನೇ ಜಯಂತಿಯನ್ನು ಹಿರಿಮೆಯ ಹಬ್ಬವಾಗಿ ಆಚರಿಸಬೇಕು ಎಂದು ಹೇಳಿದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  citizenship amendment act is not a law to take away citizenship, it is a law to grant citizenship : pm
# Actual:  ಪೌರತ್ವ ತಿದ್ದುಪಡಿ ಕಾಯ್ದೆ, ಕಸಿದು ಕೊಳ್ಳುವ ಕಾನೂನಲ್ಲ, ಬದಲಿಗೆ ಪೌರತ್ವ ನೀಡುವ ಕಾನೂನು: ಪ್ರಧಾನಮಂತ್ರಿ
# Predicted:  ಪೌರತ್ವ ತಿದ್ದುಪಡಿ ಕಾಯ್ದೆ, ಕಸಿದು ಕೊಳ್ಳುವ ಕಾನೂನಲ್ಲ, ಬದಲಿಗೆ ಪೌರತ್ವ ನೀಡುವ ಕಾನೂನು: ಪ್ರಧಾನಮಂತ್ರಿ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  pm attends the centenary celebrations of kirloskar brothers ltd
# Actual:  ಕಿರ್ಲೊಸ್ಕರ್ ಬ್ರದರ್ಸ್ ಲಿಮಿಟೆಡ್ ನ ಶತಮಾನೋತ್ಸವ ಸಮಾರಂಭದಲ್ಲಿ ಪ್ರಧಾನ ಮಂತ್ರಿ
# Predicted:  ಕಿರ್ಲೊಸ್ಕರ್ ಬ್ರದರ್ಸ್ ಲಿಮಿಟೆಡ್ ನ ಶತಮಾನೋತ್ಸವ ಸಮಾರಂಭದಲ್ಲಿ ಪ್ರಧಾನ ಮಂತ್ರಿ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  in september last year, i had the honour of saying a few lines in tamil during my united nations addresse said
# Actual:  ಕಳೆದ ವರ್ಷ ಸೆಪ್ಟೆಂಬರ್ ನಲ್ಲಿ ನನ್ನ ವಿಶ್ವ ಸಂಸ್ಥೆಯ ಭಾಷಣದ ವೇಳೆ ಕೆಲವು ಸಾಲುಗಳನ್ನು ತಮಿಳು ಭಾಷೆಯಲ್ಲಿ ಹೇಳುವ ಗೌರವ ನನಗೆ ಸಿಕ್ಕಿತ್ತು” ಎಂದು ಹೇಳಿದರು
# Predicted:  ಕಳೆದ ವರ್ಷ ಸೆಪ್ಟೆಂಬರ್ ನಲ್ಲಿ ನನ್ನ ವಿಶ್ವ ಸಂಸ್ಥೆಯ ಭಾಷಣದ ವೇಳೆ ಕೆಲವು ಸಾಲುಗಳನ್ನು ಸಾಲುಗಳನ್ನು ಎಂದು ನನಗೆ ಹೇಳಿದರು ಎಂದು ಹೇಳಿದರು ಹೇಳಿದರು
# Cumulative 1-gram: 0.735746
# Cumulative 2-gram: 0.671077
# Cumulative 3-gram: 0.623745
# Cumulative 4-gram: 0.589661
# 0.5896613549548209
#
# English:  prime minister urged everyone to visit 15 places in india in the next two years
# Actual:  ಪ್ರಧಾನಮಂತ್ರಿಗಳು ಮುಂದಿನ ಎರಡು ವರ್ಷಗಳಲ್ಲಿ ದೇಶದ ಪ್ರತಿಯೊಬ್ಬ ಪ್ರಜೆಯೂ ಭಾರತದ 15 ಸ್ಥಳಗಳಿಗೆ ಭೇಟಿ ನೀಡುವಂತೆ ಕೋರಿದರು
# Predicted:  ಪ್ರಧಾನಮಂತ್ರಿಗಳು ಮುಂದಿನ ಎರಡು ವರ್ಷಗಳಲ್ಲಿ ದೇಶದ ಪ್ರತಿಯೊಬ್ಬ ಪ್ರಜೆಯೂ ಭಾರತದ 15 ಸ್ಥಳಗಳಿಗೆ ಭೇಟಿ ನೀಡುವಂತೆ ಕೋರಿದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  so has the foreign exchange earned from tourism he said
# Actual:  ಇದರಿಂದಾಗಿ ಪ್ರವಾಸೋದ್ಯಮದಿಂದ ಹೆಚ್ಚಿನ ವಿದೇಶಿ ವಿನಿಮಯವನ್ನು ಗಳಿಸಲಾಗಿದೆ” ಎಂದು ಹೇಳಿದರು
# Predicted:  ಇದರಿಂದಾಗಿ ಪ್ರವಾಸೋದ್ಯಮದಿಂದ ಹೆಚ್ಚಿನ ವಿದೇಶಿ ವಿನಿಮಯವನ್ನು ಗಳಿಸಲಾಗಿದೆ” ಎಂದು ಹೇಳಿದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  as you all are aware, agriculture plays a vital role in the overall growth of the economy
# Actual:  ನೀವೆಲ್ಲರೂ ತಿಳಿದಿರುವಂತೆ, ಆರ್ಥಿಕತೆಯ ಒಟ್ಟಾರೆ ಬೆಳವಣಿಗೆಯಲ್ಲಿ ಕೃಷಿ ಪ್ರಮುಖ ಪಾತ್ರ ವಹಿಸುತ್ತದೆ
# Predicted:  ನೀವೆಲ್ಲರೂ ತಿಳಿದಿರುವಂತೆ, ಆರ್ಥಿಕತೆಯ ಒಟ್ಟಾರೆ ಬೆಳವಣಿಗೆಯಲ್ಲಿ ಕೃಷಿ ಪ್ರಮುಖ ಪಾತ್ರ ವಹಿಸುತ್ತದೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  as you all are aware, agriculture plays a vital role in the overall growth of the economy
# Actual:  ನೀವೆಲ್ಲರೂ ತಿಳಿದಿರುವಂತೆ, ಆರ್ಥಿಕತೆಯ ಒಟ್ಟಾರೆ ಬೆಳವಣಿಗೆಯಲ್ಲಿ ಕೃಷಿ ಪ್ರಮುಖ ಪಾತ್ರ ವಹಿಸುತ್ತದೆ
# Predicted:  ನೀವೆಲ್ಲರೂ ತಿಳಿದಿರುವಂತೆ, ಆರ್ಥಿಕತೆಯ ಒಟ್ಟಾರೆ ಬೆಳವಣಿಗೆಯಲ್ಲಿ ಕೃಷಿ ಪ್ರಮುಖ ಪಾತ್ರ ವಹಿಸುತ್ತದೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  he expressed his satisfaction at the steady progress in the multi-faceted relationship between the two countries
# Actual:  ಎರಡೂ ದೇಶಗಳ ನಡುವೆ ಬಹು ಆಯಾಮದ ಸಂಬಂಧಗಳ ಸ್ಥಿರ ಪ್ರಗತಿಯ ಬಗ್ಗೆ ಅವರು ತೃಪ್ತಿ ವ್ಯಕ್ತಪಡಿಸಿದರು
# Predicted:  ಭಾರತ ಮತ್ತು ಸ್ವೀಡನ್ ನಡುವೆ ನಡುವೆ ನಡುವೆ ನಡುವೆ ನಡುವೆ ನಡುವೆ ಪರಿಣತಿಯನ್ನು ಪರಸ್ಪರ ಹಂಚಿಕೊಳ್ಳಲು ಅನುವು ಮಾಡಿಕೊಡುತ್ತದೆ
# Cumulative 1-gram: 0.071429
# Cumulative 2-gram: 0.000000
# Cumulative 3-gram: 0.000000
# Cumulative 4-gram: 0.000000
# 9.418382295637229e-232
#
# English:  on the occasion, he launched the interactive light & sound show of rabindra setu (howrah bridge) in kolkata
# Actual:  ಈ ಸಂದರ್ಭದಲ್ಲಿ ಅವರು ಕೋಲ್ಕತ್ತಾದ ರಬೀಂದ್ರ ಸೇತುವೆ (ಹೌರಾ ಸೇತುವೆ)ಯ ಸಂವಾದನಾತ್ಮಕ ಧ್ವನಿ ಮತ್ತು ಬೆಳಕಿನ ಪ್ರದರ್ಶನಕ್ಕೆ ಚಾಲನೆ ನೀಡಿದರು
# Predicted:  ಈ ಸಂದರ್ಭದಲ್ಲಿ ಅವರು ಕೋಲ್ಕತ್ತಾದ ರಬೀಂದ್ರ ಸೇತುವೆ (ಹೌರಾ ಸೇತುವೆ)ಯ ಸಂವಾದನಾತ್ಮಕ ಧ್ವನಿ ಮತ್ತು ಬೆಳಕಿನ ಪ್ರದರ್ಶನಕ್ಕೆ ಚಾಲನೆ ನೀಡಿದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  cabinet approves ratification of migration and mobility partnership agreement between india and france
# Actual:  ಭಾರತ ಮತ್ತು ಫ್ರಾನ್ಸ್ ನಡುವಿನ ವಲಸೆ ಮತ್ತು ಸಂಚಾರ ಪಾಲುದಾರಿಕೆ ಒಪ್ಪಂದಕ್ಕೆ ಸಂಪುಟದ ಅನುಮೋದನೆ
# Predicted:  ಭಾರತ ಮತ್ತು ಫ್ರಾನ್ಸ್ ನಡುವಿನ ವಲಸೆ ಮತ್ತು ಸಂಚಾರ ಪಾಲುದಾರಿಕೆ ಒಪ್ಪಂದಕ್ಕೆ ಸಂಪುಟದ ಅನುಮೋದನೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  addressing the gathering the prime minister said, indian thought is vibrant and diverset is constant and evolving
# Actual:  ಸಭಿಕರನ್ನುದ್ದೇಶಿಸಿ ಭಾಷಣ ಮಾಡಿದ ಪ್ರಧಾನಮಂತ್ರಿ ಅವರು, “ಭಾರತೀಯರ ಚಿಂತನೆಗಳು ಪ್ರಕರವಾಗಿವೆ ಮತ್ತು ವಿಭಿನ್ನವಾಗಿವೆ
# Predicted:  ಸಭಿಕರನ್ನುದ್ದೇಶಿಸಿ ಭಾಷಣ ಮಾಡಿದ ಪ್ರಧಾನಮಂತ್ರಿ ಅವರು, “ಭಾರತೀಯರ ಚಿಂತನೆಗಳು ಪ್ರಕರವಾಗಿವೆ ಮತ್ತು ವಿಭಿನ್ನವಾಗಿವೆ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  cabinet apprised of information about amendments to the motor vehicles (amendment) bill, 2019
# Actual:  ಮೋಟಾರು ವಾಹನಗಳ (ತಿದ್ದುಪಡಿ) ಮಸೂದೆ, 2019 ರ ತಿದ್ದುಪಡಿಗಳ ಮಾಹಿತಿಗೆ ಸಂಪುಟದ ಅನುಮೋದನೆ
# Predicted:  ಮೋಟಾರು ವಾಹನಗಳ (ತಿದ್ದುಪಡಿ) ಮಸೂದೆ, 2019 ರ ಜುಲೈ 23 ರಂದು ಲೋಕಸಭೆಯಲ್ಲಿ ಅಂಗೀಕರಿಸಲ್ಪಟ್ಟಿತು
# Cumulative 1-gram: 0.545455
# Cumulative 2-gram: 0.522233
# Cumulative 3-gram: 0.498391
# Cumulative 4-gram: 0.461737
# 0.4617366309441026
#
# English:  in september last year, i had the honour of saying a few lines in tamil during my united nations addresse said
# Actual:  ಕಳೆದ ವರ್ಷ ಸೆಪ್ಟೆಂಬರ್ ನಲ್ಲಿ ನನ್ನ ವಿಶ್ವ ಸಂಸ್ಥೆಯ ಭಾಷಣದ ವೇಳೆ ಕೆಲವು ಸಾಲುಗಳನ್ನು ತಮಿಳು ಭಾಷೆಯಲ್ಲಿ ಹೇಳುವ ಗೌರವ ನನಗೆ ಸಿಕ್ಕಿತ್ತು” ಎಂದು ಹೇಳಿದರು
# Predicted:  ಕಳೆದ ವರ್ಷ ಸೆಪ್ಟೆಂಬರ್ ನಲ್ಲಿ ನನ್ನ ವಿಶ್ವ ಸಂಸ್ಥೆಯ ಭಾಷಣದ ವೇಳೆ ಕೆಲವು ಸಾಲುಗಳನ್ನು ಸಾಲುಗಳನ್ನು ಎಂದು ನನಗೆ ಹೇಳಿದರು ಎಂದು ಹೇಳಿದರು
# Cumulative 1-gram: 0.732126
# Cumulative 2-gram: 0.668933
# Cumulative 3-gram: 0.622545
# Cumulative 4-gram: 0.590096
# 0.590096156808963
#
# English:  friends, first and foremost i wish you all a happy 2020
# Actual:  ಸ್ನೇಹಿತರೇ, ಮೊದಲನೆಯದಾಗಿ ನಿಮ್ಮೆಲ್ಲರಿಗೂ 2020 ರ ಶುಭಾಶಯಗಳು
# Predicted:  ಸ್ನೇಹಿತರೇ, ಮೊದಲನೆಯದಾಗಿ ನಿಮ್ಮೆಲ್ಲರಿಗೂ 2020 ರ ಶುಭಾಶಯಗಳು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  he highlighted that india now stands at 3rdposition globally, in the number of peer-reviewed science and engineering publications
# Actual:  ಉತ್ತಮ ವಿಮರ್ಶೆಯ ವಿಜ್ಞಾನ ಮತ್ತು ಎಂಜಿನಿಯರಿಂಗ್ ಪ್ರಕಟಣೆಗಳ ಸಂಖ್ಯೆಯಲ್ಲಿ ಭಾರತ ಈಗ ಜಾಗತಿಕವಾಗಿ 3 ನೇ ಸ್ಥಾನದಲ್ಲಿರುವ ಬಗ್ಗೆ ಅವರು ಪ್ರಸ್ತಾಪಿಸಿದರು
# Predicted:  ಉತ್ತಮ ವಿಮರ್ಶೆಯ ವಿಜ್ಞಾನ ಮತ್ತು ಎಂಜಿನಿಯರಿಂಗ್ ಪ್ರಕಟಣೆಗಳ ಸಂಖ್ಯೆಯಲ್ಲಿ ಭಾರತ ಈಗ ಜಾಗತಿಕವಾಗಿ 3 ನೇ ಸ್ಥಾನದಲ್ಲಿರುವ ಬಗ್ಗೆ ಅವರು ಪ್ರಸ್ತಾಪಿಸಿದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  now he can directly connect with the government and make his voice heard
# Actual:  ಈಗ ಅವರು ನೇರವಾಗಿ ಸರ್ಕಾರದೊಂದಿಗೆ ಸಂಪರ್ಕ ಸಾಧಿಸಬಹುದು ಮತ್ತು ಅವರ ಮಾತನ್ನು ಕೇಳುವಂತೆ ಮಾಡಬಹುದು ” ಎಂದರು
# Predicted:  ಈಗ ಅವರು ನೇರವಾಗಿ ಸರ್ಕಾರದೊಂದಿಗೆ ಸಂಪರ್ಕ ಸಾಧಿಸಬಹುದು ಮತ್ತು ಅವರ ಮಾತನ್ನು ಕೇಳುವಂತೆ ಮಾಡಬಹುದು ” ಎಂದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  pm condoles demise of drchidananda murthy
# Actual:  ಎಂ ಿದಾನಂದ ಮೂರ್ತಿ ನಿಧನಕ್ಕೆ ಪ್ರಧಾನಮಂತ್ರಿ ಸಂತಾಪ
# Predicted:  ಡಾ ಂ ಿದಾನಂದ ಮೂರ್ತಿ ನಿಧನಕ್ಕೆ ಪ್ರಧಾನಮಂತ್ರಿ ಸಂತಾಪ
# Cumulative 1-gram: 0.714286
# Cumulative 2-gram: 0.690066
# Cumulative 3-gram: 0.661390
# Cumulative 4-gram: 0.614788
# 0.6147881529512643
#
# English:  this will save the environment and will also develop our small scale industries
# Actual:  ಇದು ಪರಿಸರವನ್ನು ಉಳಿಸುತ್ತದೆ ಮತ್ತು ನಮ್ಮ ಸಣ್ಣ ಕೈಗಾರಿಕೆಗಳನ್ನು ಸಹ ಅಭಿವೃದ್ಧಿಪಡಿಸುತ್ತದೆ
# Predicted:  ಇದು ಪರಿಸರವನ್ನು ಉಳಿಸುತ್ತದೆ ಮತ್ತು ನಮ್ಮ ಸಣ್ಣ ಕೈಗಾರಿಕೆಗಳನ್ನು ಸಹ ಅವರು
# Cumulative 1-gram: 0.888889
# Cumulative 2-gram: 0.881917
# Cumulative 3-gram: 0.874762
# Cumulative 4-gram: 0.863340
# 0.8633400213704505
#
# English:  similarly the lion population has grown up 30% from 2010 to 2015, he said
# Actual:  ಅದೇ ರೀತಿ ಸಿಂಹಗಳ ಸಂಖ್ಯೆಯೂ 2010ರಿಂದ 2015ರ ನಡುವೆ ಶೇ
# Predicted:  ಇದರಿಂದಾಗಿ ಪ್ರವಾಸೋದ್ಯಮದಿಂದ ಹೆಚ್ಚಿನ ವಿದೇಶಿ 2010ರಿಂದ 2015ರ ನಡುವೆ ಶೇ
# Cumulative 1-gram: 0.500000
# Cumulative 2-gram: 0.462910
# Cumulative 3-gram: 0.418579
# Cumulative 4-gram: 0.345721
# 0.345720784641941
#
# English:  merely knowledge of technology isnt enough
# Actual:  ಕೇವಲ ತಂತ್ರಜ್ಞಾನದ ಜ್ಞಾನವು ಸಾಕಾಗುವುದಿಲ್ಲ
# Predicted:  ಕೇವಲ ತಂತ್ರಜ್ಞಾನದ ಜ್ಞಾನವು ಸಾಕಾಗುವುದಿಲ್ಲ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  it became possible with the help of aadhaar enabled technology
# Actual:  ಆಧಾರ್ ಆಧಾರಿತ ತಂತ್ರಜ್ಞಾನದ ಸಹಾಯದಿಂದ
# Predicted:  ಆಧಾರ್ ಆಧಾರಿತ ತಂತ್ರಜ್ಞಾನದ ಸಹಾಯದಿಂದ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  i would urge students to be confident about their own preparation
# Actual:  ವಿದ್ಯಾರ್ಥಿಗಳು ತಮ್ಮದೇ ಆದ ತಯಾರಿಯ ಬಗ್ಗೆ ವಿಶ್ವಾಸ ಹೊಂದಿರಬೇಕು
# Predicted:  ವಿದ್ಯಾರ್ಥಿಗಳು ತಮ್ಮದೇ ಆದ ತಯಾರಿಯ ಬಗ್ಗೆ ವಿಶ್ವಾಸ ಹೊಂದಿರಬೇಕು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  tributes to iconic leaders of bengal
# Actual:  ಬಂಗಾಲದ ಮೇರು ನಾಯಕರಿಗೆ ಶ್ರದ್ಧಾಂಜಲಿ
# Predicted:  ಬಂಗಾಲದ ಮೇರು ನಾಯಕರಿಗೆ ಶ್ರದ್ಧಾಂಜಲಿ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  he reiterated indias continued commitment to developing her strong and friendly relations with iran
# Actual:  ಪ್ರಧಾನಿ ಅವರು, ಇರಾನ್ ಜೊತೆಗಿನ ಬಲಿಷ್ಠ ಮತ್ತು ಸ್ನೇಹ ಸಂಬಂಧಗಳನ್ನು ಅಭಿವೃದ್ಧಿಗೊಳಿಸಲು ಭಾರತದ ಬದ್ಧತೆ ಮುಂದುವರಿಯಲಿದೆ ಎಂದು ಪುನರುಚ್ಚರಿಸಿದರು
# Predicted:  ಪ್ರಧಾನಿ ಅವರು, ಇರಾನ್ ಜೊತೆಗಿನ ಬಲಿಷ್ಠ ಮತ್ತು ಸ್ನೇಹ ಸಂಬಂಧಗಳನ್ನು ಅಭಿವೃದ್ಧಿಗೊಳಿಸಲು ಭಾರತದ ಬದ್ಧತೆ ಮುಂದುವರಿಯಲಿದೆ ಎಂದು ಪುನರುಚ್ಚರಿಸಿದರು
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  another important link in the economy of the village is our micro, small and medium enterprises i  e
# Actual:  ಗ್ರಾಮೀಣ ಆರ್ಥಿಕತೆಯ ಮತ್ತೊಂದು ಪ್ರಮುಖ ಕೊಂಡಿಯೆಂದರೆ ನಮ್ಮ ಸಣ್ಣ ಮತ್ತು ಮಧ್ಯಮ ಪ್ರಮಾಣದ ಉದ್ಯಮ ಅಂದರೆ ಎಂಎಸ್‌ಎಂಇ
# Predicted:  ಗ್ರಾಮೀಣ ಆರ್ಥಿಕತೆಯ ಮತ್ತೊಂದು ಪ್ರಮುಖ ಕೊಂಡಿಯೆಂದರೆ ನಮ್ಮ ಸಣ್ಣ ಮತ್ತು ಮಧ್ಯಮ ಪ್ರಮಾಣದ ಉದ್ಯಮ ಅಂದರೆ ಎಂಎಸ್‌ಎಂಇ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  can we find farmer-centric solutions to the problem of stalk burning for instance
# Actual:  ಉದಾಹರಣೆಗೆ ಕಾಂಡವನ್ನು ಸುಡುವ ಸಮಸ್ಯೆಗೆ ನಾವು ರೈತ-ಕೇಂದ್ರಿತ ಪರಿಹಾರಗಳನ್ನು ಕಂಡುಹಿಡಿಯಬಹುದೇ
# Predicted:  ಉದಾಹರಣೆಗೆ ಕಾಂಡವನ್ನು ಸುಡುವ ಸಮಸ್ಯೆಗೆ ನಾವು ರೈತ-ಕೇಂದ್ರಿತ ಪರಿಹಾರಗಳನ್ನು ಕಂಡುಹಿಡಿಯಬಹುದೇ
# Cumulative 1-gram: 1.000000
# Cumulative 2-gram: 1.000000
# Cumulative 3-gram: 1.000000
# Cumulative 4-gram: 1.000000
# 1.0
#
# English:  pm condoles demise of drchidananda murthy
# Actual:  ಎಂ ಿದಾನಂದ ಮೂರ್ತಿ ನಿಧನಕ್ಕೆ ಪ್ರಧಾನಮಂತ್ರಿ ಸಂತಾಪ
# Predicted:  ಡಾ ಂ ಿದಾನಂದ ಮೂರ್ತಿ ನಿಧನಕ್ಕೆ ಪ್ರಧಾನಮಂತ್ರಿ ಸಂತಾಪ
# Cumulative 1-gram: 0.714286
# Cumulative 2-gram: 0.690066
# Cumulative 3-gram: 0.661390
# Cumulative 4-gram: 0.614788
# 0.6147881529512643
#
# Average BLEU score
# 0.7771767111708101

# %% [markdown]
# # Visualizing attention

# %%
output_words, attentions = evaluate(
    encoder1, attn_decoder1, "you do your ")
plt.matshow(attentions.numpy())

# %%
def showAttention(input_sentence, output_words, attentions):
    # %matplotlib inline
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    
    plt.show()


def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions)

# %%
evaluateAndShowAttention("pm visit karnataka on 2nd and 3rd january 2020")
# Out:
# input = pm visit karnataka on 2nd and 3rd january 2020
# output = 2020ರ ಜನವರಿ 2 ಮತ್ತು 3ರಂದು ಕರ್ನಾಟಕಕ್ಕೆ ಪ್ರಧಾನಮಂತ್ರಿ ಭೇಟಿ
